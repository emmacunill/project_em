# %%
import pandas as pd
import os
import numpy as np

# %%
csv_file = "data/attacks.csv"
sharks = pd.read_csv(csv_file, encoding = "ISO-8859-1")
sharks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %% [markdown]
# **EXPLORATION**

# %%
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
sharks.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
sharks.shape
# Out:
# (25723, 24)

# %%
sharks.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
sharks.isna().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
sharks.notna().sum()
# Out:
# Case Number               8702
# Date                      6302
# Year                      6300
# Type                      6298
# Country                   6252
# Area                      5847
# Location                  5762
# Activity                  5758
# Name                      6092
# Sex                       5737
# Age                       3471
# Injury                    6274
# Fatal (Y/N)               5763
# Time                      2948
# Species                   3464
# Investigator or Source    6285
# pdf                       6302
# href formula              6301
# href                      6302
# Case Number.1             6302
# Case Number.2             6302
# original order            6309
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %%
sharks.isna()
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
#         Name   Sex   ...  Species   Investigator or Source    pdf  \
# 0      False  False  ...     False                   False  False
# 1      False  False  ...      True                   False  False
# 2      False  False  ...      True                   False  False
# 3      False  False  ...     False                   False  False
# 4      False  False  ...     False                   False  False
# ...      ...    ...  ...       ...                     ...    ...
# 25718   True   True  ...      True                    True   True
# 25719   True   True  ...      True                    True   True
# 25720   True   True  ...      True                    True   True
# 25721   True   True  ...      True                    True   True
# 25722   True   True  ...      True                    True   True
#
#        href formula   href  Case Number.1  Case Number.2  original order  \
# 0             False  False          False          False           False
# 1             False  False          False          False           False
# 2             False  False          False          False           False
# 3             False  False          False          False           False
# 4             False  False          False          False           False
# ...             ...    ...            ...            ...             ...
# 25718          True   True           True           True            True
# 25719          True   True           True           True            True
# 25720          True   True           True           True            True
# 25721          True   True           True           True            True
# 25722          True   True           True           True            True
#
#        Unnamed: 22  Unnamed: 23
# 0             True         True
# 1             True         True
# 2             True         True
# 3             True         True
# 4             True         True
# ...            ...          ...
# 25718         True         True
# 25719         True         True
# 25720         True         True
# 25721         True         True
# 25722         True         True
#
# [25723 rows x 24 columns]

# %%
sharks.sample(10)
# Out:
#         Case Number         Date    Year        Type Country        Area  \
# 23666           NaN          NaN     NaN         NaN     NaN         NaN
# 18451           NaN          NaN     NaN         NaN     NaN         NaN
# 12547           NaN          NaN     NaN         NaN     NaN         NaN
# 16810           NaN          NaN     NaN         NaN     NaN         NaN
# 10545           NaN          NaN     NaN         NaN     NaN         NaN
# 2669   1989.08.22.b  22-Aug-1989  1989.0  Unprovoked     USA     Florida
# 20881           NaN          NaN     NaN         NaN     NaN         NaN
# 1183     2008.12.20  20-Dec-2008  2008.0     Boating     USA  California
# 18397           NaN          NaN     NaN         NaN     NaN         NaN
# 8968            NaN          NaN     NaN         NaN     NaN         NaN
#
#                             Location  Activity              Name Sex   ...  \
# 23666                            NaN       NaN               NaN  NaN  ...
# 18451                            NaN       NaN               NaN  NaN  ...
# 12547                            NaN       NaN               NaN  NaN  ...
# 16810                            NaN       NaN               NaN  NaN  ...
# 10545                            NaN       NaN               NaN  NaN  ...
# 2669   St Augustine, St Johns County  Swimming  Anthony McKnight    M  ...
# 20881                            NaN       NaN               NaN  NaN  ...
# 1183      Dillon Beach, Marin County  Kayaking      Tony Johnson    M  ...
# 18397                            NaN       NaN               NaN  NaN  ...
# 8968                             NaN       NaN               NaN  NaN  ...
#
#                Species              Investigator or Source  \
# 23666               NaN                                NaN
# 18451               NaN                                NaN
# 12547               NaN                                NaN
# 16810               NaN                                NaN
# 10545               NaN                                NaN
# 2669   1.2 m [4'] shark  Orlando Sentinel, 8/24/1989. p.B1
# 20881               NaN                                NaN
# 1183        White shark                         R. Collier
# 18397               NaN                                NaN
# 8968                NaN                                NaN
#
#                              pdf  \
# 23666                        NaN
# 18451                        NaN
# 12547                        NaN
# 16810                        NaN
# 10545                        NaN
# 2669   1989.08.22.b-McKnight.pdf
# 20881                        NaN
# 1183      2008.12.20-Johnson.pdf
# 18397                        NaN
# 8968                         NaN
#
#                                             href formula  \
# 23666                                                NaN
# 18451                                                NaN
# 12547                                                NaN
# 16810                                                NaN
# 10545                                                NaN
# 2669   http://sharkattackfile.net/spreadsheets/pdf_di...
# 20881                                                NaN
# 1183   http://sharkattackfile.net/spreadsheets/pdf_di...
# 18397                                                NaN
# 8968                                                 NaN
#
#                                                     href Case Number.1  \
# 23666                                                NaN           NaN
# 18451                                                NaN           NaN
# 12547                                                NaN           NaN
# 16810                                                NaN           NaN
# 10545                                                NaN           NaN
# 2669   http://sharkattackfile.net/spreadsheets/pdf_di...  1989.08.22.b
# 20881                                                NaN           NaN
# 1183   http://sharkattackfile.net/spreadsheets/pdf_di...    2008.12.20
# 18397                                                NaN           NaN
# 8968                                                 NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 23666           NaN            NaN         NaN         NaN
# 18451           NaN            NaN         NaN         NaN
# 12547           NaN            NaN         NaN         NaN
# 16810           NaN            NaN         NaN         NaN
# 10545           NaN            NaN         NaN         NaN
# 2669   1989.08.22.b         3634.0         NaN         NaN
# 20881           NaN            NaN         NaN         NaN
# 1183     2008.12.20         5120.0         NaN         NaN
# 18397           NaN            NaN         NaN         NaN
# 8968            NaN            NaN         NaN         NaN
#
# [10 rows x 24 columns]

# %%
sharks['Sex '].value_counts()
# Out:
# Sex
# M      5094
# F       637
# M         2
# N         2
# lli       1
# .         1
# Name: count, dtype: int64

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks["Fatal (Y/N)"].value_counts()
# Out:
# Fatal (Y/N)
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: count, dtype: int64

# %%
sharks["Species "].value_counts()
# Out:
# Species
# White shark                                                                                                                      163
# Shark involvement prior to death was not confirmed                                                                               105
# Invalid                                                                                                                          102
# Shark involvement not confirmed                                                                                                   88
# Tiger shark                                                                                                                       73
#                                                                                                                                 ...
# 1.2 m to 1.5 m [4.5' to 5'] shark                                                                                                  1
# Bull shark, 2.3 m [7.5']                                                                                                           1
# 0.9 m  [3'] shark                                                                                                                  1
# Mako shark, 14'                                                                                                                    1
# Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable      1
# Name: count, Length: 1549, dtype: int64

# %%
sharks["Investigator or Source"].value_counts()
# Out:
# Investigator or Source
# C. Moore, GSAF                                                    105
# C. Creswell, GSAF                                                  92
# S. Petersohn, GSAF                                                 82
# R. Collier                                                         55
# T. Peake, GSAF                                                     48
#                                                                  ...
# Deseret News, 2/19/1996; European Stars and Stripes, 2/20/1996      1
# Daily Telegraph, 2/29/1996, p.5; H. Edwards, pp.31-32               1
# J. Royle, et. al. (1997)                                            1
# Advertiser, 3/6/1996, p.9; Daily Mail (London), 3/9/1996            1
# S.W. Baker                                                          1
# Name: count, Length: 4969, dtype: int64

# %%
sharks["Country"].value_counts()
# Out:
# Country
# USA                       2229
# AUSTRALIA                 1338
# SOUTH AFRICA               579
# PAPUA NEW GUINEA           134
# NEW ZEALAND                128
#                           ...
# MALDIVE ISLANDS              1
# NICARAGUA                    1
# NORTH SEA                    1
# RED SEA / INDIAN OCEAN       1
# CEYLON (SRI LANKA)           1
# Name: count, Length: 212, dtype: int64

# %%
sharks["Location"].value_counts()
# Out:
# Location
# New Smyrna Beach, Volusia County                  163
# Daytona Beach, Volusia County                      30
# Ponce Inlet, Volusia County                        20
# Melbourne Beach, Brevard County                    18
# Myrtle Beach, Horry County                         17
#                                                  ...
# Whale Beach                                         1
# l'Anse-Vata                                         1
# Hole-in-the Wall                                    1
# Wreck of the Navy Barge, 22 miles SE of Rudee       1
# Below the English fort, Trincomalee                 1
# Name: count, Length: 4108, dtype: int64

# %%
sharks["Area"].value_counts()
# Out:
# Area
# Florida                                 1037
# New South Wales                          486
# Queensland                               311
# Hawaii                                   298
# California                               290
#                                         ...
# Ysabel Island                              1
#  Lau Province                              1
# South Coast, East New Britain              1
# Between Southampton & Canary Islands       1
# Moala Island                               1
# Name: count, Length: 825, dtype: int64

# %%
sharks["Activity"].value_counts()
# Out:
# Activity
# Surfing                                   971
# Swimming                                  869
# Fishing                                   431
# Spearfishing                              333
# Bathing                                   162
#                                          ...
# Playing with a frisbee in the shallows      1
# Sinking of the ferryboat Dumaguete          1
# Wreck of the Storm King                     1
# Feeding mullet to sharks                    1
# Wreck of  large double sailing canoe        1
# Name: count, Length: 1532, dtype: int64

# %%
sharks["Injury"].value_counts()
# Out:
# Injury
# FATAL                                                                                     802
# Survived                                                                                   97
# Foot bitten                                                                                87
# No injury                                                                                  82
# Leg bitten                                                                                 72
#                                                                                          ...
# Cut foot, but injury caused by fishing line, not the shark                                  1
# Left foot bitten after he accidentally stepped on the shark         PROVOKED INCIDENT       1
# 2 puncture wounds in left leg                                                               1
# PROVOKED INCIDENT    Knee bitten by shark trapped in net                                    1
# FATAL. "Shark bit him in half, carrying away the lower extremities"                         1
# Name: count, Length: 3737, dtype: int64

# %%
sharks["Injury"].sample(15)
# Out:
# 3932                      Leg bitten
# 3503                 Left foot bitten
# 11082                             NaN
# 5159                       No details
# 15356                             NaN
# 600           No injury, board bitten
# 9108                              NaN
# 1304      Lacerations to left forearm
# 5579                            FATAL
# 24423                             NaN
# 3988     Lower left leg & foot bitten
# 8285                              NaN
# 13630                             NaN
# 18073                             NaN
# 3369         Lacerations to left leg
# Name: Injury, dtype: object

# %%
sharks["Year"].value_counts()
# Out:
# Year
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1786.0      1
# 1785.0      1
# 1784.0      1
# 1783.0      1
# 1815.0      1
# Name: count, Length: 249, dtype: int64

# %%
sharks["Type"].value_counts()
# Out:
# Type
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: count, dtype: int64

# %%
sharks.rename(columns={"Sex ":"Sex"})
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name  Sex  ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
sharks.rename(columns={"Species ":"Species"})
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...          Species  \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks[sharks["Type"] == "Invalid"]
# Out:
#        Case Number                      Date    Year     Type  \
# 2       2018.06.09               09-Jun-2018  2018.0  Invalid
# 13    2018.05.13.a               13-May-2018  2018.0  Invalid
# 31    2018.04.10.R      Reported 10-Apr-2018  2018.0  Invalid
# 43      2018.02.14               14-Feb-2018  2018.0  Invalid
# 44      2018.02.11               11-Feb-2018  2018.0  Invalid
# ...            ...                       ...     ...      ...
# 6147    1767.00.00                      1767  1767.0  Invalid
# 6157    1733.00.00                      1733  1733.0  Invalid
# 6164  1642.00.00.b  Late 1600s Reported 1728  1642.0  Invalid
# 6227       ND.0086      No date, Before 1975     0.0  Invalid
# 6232       ND.0081      No date, Before 1963     0.0  Invalid
#
#                Country                  Area  \
# 2                  USA                Hawaii
# 13             ENGLAND              Cornwall
# 31              BRAZIL               Alagoas
# 43           AUSTRALIA            Queensland
# 44              BRAZIL  Boi Island, Victoria
# ...                ...                   ...
# 6147            FRANCE          Côte d'Azur
# 6157           ICELAND           Bardestrand
# 6164            GUINEA                   NaN
# 6227  PAPUA NEW GUINEA   Milne Bay  Province
# 6232               USA                Hawaii
#
#                                               Location        Activity  \
# 2                                         Habush, Oahu         Surfing
# 13                                      Off Land's End         Fishing
# 31                           Praia de Sauaçuhy, Maceió         Fishing
# 43                                    Mooloolaba Beach        Swimming
# 44                                      Espirito Santo   Cleaning fish
# ...                                                ...             ...
# 6147                                        St. Tropez         Bathing
# 6157                                      Talkknefiord             NaN
# 6164                                               NaN  Went overboard
# 6227   D'Entrecasteaux islands, 20 miles off the coast    Scuba diving
# 6232                                    Portlock, Oahu          Diving
#
#                                Name Sex   ...  \
# 2                       John Denges    M  ...
# 13                     Max Berryman    M  ...
# 31                       Josias Paz    M  ...
# 43                      Sharna Babd    F  ...
# 44                   Rosalida Souza    F  ...
# ...                             ...  ...  ...
# 6147                Samuel Matthews    M  ...
# 6157                            NaN  NaN  ...
# 6164  crew member of the Nieuwstadt    M  ...
# 6227                      Dan Hogan    M  ...
# 6232                  Val Valentine    M  ...
#
#                                            Species   \
# 2                                               NaN
# 13                                 Invalid incident
# 31                  Shark involvement not confirmed
# 43                             Possibly a wobbegong
# 44    Injury believed caused by an eel, not a shark
# ...                                             ...
# 6147        Description of shark does not ring true
# 6157   Shark involvement prior to death unconfirmed
# 6164                                   Questionable
# 6227                                   Questionable
# 6232                                        Invalid
#
#                                  Investigator or Source  \
# 2                        K.McMurray, TrackingSharks.com
# 13                      K. McMurray, TrackingSharks.com
# 31                      K. McMurray, TrackingSharks.com
# 43                      Sunshine Coast Daily, 2/15/2018
# 44                                   TrackingSharks.com
# ...                                                 ...
# 6147                                                NaN
# 6157                                         E. Olafsen
# 6164  History of the Pyrates, by D. Defoe, Vol. 2, p.28
# 6227                                F. Dennis, pp.15-16
# 6232                                B. Sojka & D. Lloyd
#
#                               pdf  \
# 2           2018.06.09-Denges.pdf
# 13      2018.05.13.a-Berryman.pdf
# 31           2018.04.10.R-Paz.pdf
# 43            2018.02.14-Babd.pdf
# 44         2018.02.11-Rosilda.pdf
# ...                           ...
# 6147      1767.00.00-Matthews.pdf
# 6157       1733.00.00-Iceland.pdf
# 6164  1642.00.00.b-Nieuwstadt.pdf
# 6227         ND-0086-DanHogan.pdf
# 6232        ND-0081-Valentine.pdf
#
#                                            href formula  \
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...
# 31    http://sharkattackfile.net/spreadsheets/pdf_di...
# 43    http://sharkattackfile.net/spreadsheets/pdf_di...
# 44    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6147  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6157  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6164  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6227  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6232  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.13.a
# 31    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.10.R
# 43    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.02.14
# 44    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.02.11
# ...                                                 ...           ...
# 6147  http://sharkattackfile.net/spreadsheets/pdf_di...    1767.00.00
# 6157  http://sharkattackfile.net/spreadsheets/pdf_di...    1733.00.00
# 6164  http://sharkattackfile.net/spreadsheets/pdf_di...  1642.00.00.b
# 6227  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0086
# 6232  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0081
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 2       2018.06.09         6301.0         NaN         NaN
# 13    2018.05.13.a         6290.0         NaN         NaN
# 31    2018.04.10.R         6272.0         NaN         NaN
# 43      2018.02.14         6260.0         NaN         NaN
# 44      2018.02.11         6259.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6147    1767.00.00          156.0         NaN         NaN
# 6157    1733.00.00          146.0         NaN         NaN
# 6164  1642.00.00.b          139.0         NaN         NaN
# 6227       ND.0086           76.0         NaN         NaN
# 6232       ND.0081           71.0         NaN         NaN
#
# [547 rows x 24 columns]

# %%
sharks_ti = sharks[["Type", "Injury"]]
sharks_ti
# Out:
#              Type                                             Injury
# 0         Boating  No injury to occupant, outrigger canoe and pad...
# 1      Unprovoked                         Minor injury to left thigh
# 2         Invalid       Injury to left lower leg from surfboard skeg
# 3      Unprovoked                          Minor injury to lower leg
# 4        Provoked  Lacerations to leg & hand shark PROVOKED INCIDENT
# ...           ...                                                ...
# 25718         NaN                                                NaN
# 25719         NaN                                                NaN
# 25720         NaN                                                NaN
# 25721         NaN                                                NaN
# 25722         NaN                                                NaN
#
# [25723 rows x 2 columns]

# %%
sharks_ti.isna().sum()
# Out:
# Type      19425
# Injury    19449
# dtype: int64

# %%
sharks_ti.notna().sum()
# Out:
# Type      6298
# Injury    6274
# dtype: int64

# %%
sharks_ti[sharks_ti["Type"] == "Provoked"].sample(15)
# Out:
#           Type                                             Injury
# 2692  Provoked       Thigh lacerated & abraded  PROVOKED INCIDENT
# 1013  Provoked  Small laceration to forearm from netted shark ...
# 1419  Provoked  Left arm lacerated when he grabbed shark by it...
# 951   Provoked                   Left eg bitten PROVOKED INCIDENT
# 41    Provoked  Shark rammed kayak, no injury to occupant  PRO...
# 1449  Provoked  Minor injuries, similar to paper cuts from the...
# 4240  Provoked                           FATAL, PROVOKED INCIDENT
# 4719  Provoked  Attempted to frighten shark by smacking water ...
# 4172  Provoked  Calf avulsed by shark he was holding by the ta...
# 2446  Provoked   Arm lacerated by captive shark PROVOKED INCIDENT
# 4245  Provoked  FATAL. His brother speared a shark which then ...
# 5299  Provoked  FATAL, leg severely bitten, surgically amputat...
# 3165  Provoked  No injury to occupants. Hooked shark bit boat'...
# 3226  Provoked  Slightly injured when he stepped on a shark PR...
# 4866  Provoked       Speared shark bit his hand PROVOKED INCIDENT

# %%
sharks_saf = sharks[["Sex ", "Age", "Fatal (Y/N)"]]
sharks_saf
# Out:
#       Sex   Age Fatal (Y/N)
# 0        F   57           N
# 1        F   11           N
# 2        M   48           N
# 3        M  NaN           N
# 4        M  NaN           N
# ...    ...  ...         ...
# 25718  NaN  NaN         NaN
# 25719  NaN  NaN         NaN
# 25720  NaN  NaN         NaN
# 25721  NaN  NaN         NaN
# 25722  NaN  NaN         NaN
#
# [25723 rows x 3 columns]

# %%
sharks_saf.isna().sum()
# Out:
# Sex            19986
# Age            22252
# Fatal (Y/N)    19960
# dtype: int64

# %%
sharks_saf.notna().sum()
# Out:
# Sex            5737
# Age            3471
# Fatal (Y/N)    5763
# dtype: int64

# %%
sharks_saf["Sex "].value_counts()
# Out:
# Sex
# M      5094
# F       637
# M         2
# N         2
# lli       1
# .         1
# Name: count, dtype: int64

# %%
sharks_saf.columns
# Out:
# Index(['Sex ', 'Age', 'Fatal (Y/N)'], dtype='object')

# %%
sharks_saf.rename(columns={"Sex ":"Sex"}, inplace=True)
# Out:
# /var/folders/ns/rjvmq7zn3cggtjmkkj8bhfsc0000gn/T/ipykernel_26971/137973743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_saf.rename(columns={"Sex ":"Sex"}, inplace=True)

# %%
sharks_saf.columns
# Out:
# Index(['Sex', 'Age', 'Fatal (Y/N)'], dtype='object')

# %%
sharks_saf["Sex"].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
sharks_saf[sharks_saf["Sex"] == "lli"]
# Out:
#       Sex Age Fatal (Y/N)
# 1624  lli  38           N

# %%
sharks_saf["Age"].nunique()
# Out:
# 157
